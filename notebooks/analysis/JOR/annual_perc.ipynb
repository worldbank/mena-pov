# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
from openpyxl import load_workbook
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
# Specify the base download directory
base_download_directory = "/Users/chitrab/Downloads/Annual percentages"

# Specify the path to the ChromeDriver executable
chromedriver_path = "/Users/chitrab/chromedriver_mac64/chromedriver"

# Define the range of t_no values
start_t_no = 13
end_t_no = 88

# Define the range of year1 values
start_year1 = 2000
end_year1 = 2022

# Set the download options for ChromeDriver
chrome_options = webdriver.ChromeOptions()
prefs = {
    "download.default_directory": base_download_directory,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
}
chrome_options.add_experimental_option("prefs", prefs)

# Create a ChromeDriver instance with the specified options
driver = webdriver.Chrome(chromedriver_path, options=chrome_options)

# Loop through t_no values
for t_no in range(start_t_no, end_t_no + 1):
    # Loop through year1 values
    for year1 in range(start_year1, end_year1 + 1):
        try:
            # Construct the URL with the current t_no and year1 values
            url = f"http://www.dos.gov.jo/owa-user/owa/emp_unemp_y.show_tables1_y?lang=E&year1={year1}&t_no={t_no}"

            # Open the URL
            driver.get(url)

            # Wait for the page to load (you may need to adjust the sleep duration based on the page load time)
            time.sleep(2)

            # Find the <img> element within the specified XPath
            img_element = driver.find_element(By.XPATH, '/html/body/center[3]/table/tbody/tr/td[3]/a/img')
            
            # Click on the img element
            img_element.click()

            # Wait for the file to be downloaded (you may need to adjust the sleep duration based on the file download time)
            time.sleep(5)

            # Move the downloaded file to the respective year folder
            original_file_path = os.path.join(base_download_directory, f"Table {t_no}.xls")
            year_folder_path = os.path.join(base_download_directory, str(year1))
            if not os.path.exists(year_folder_path):
                os.makedirs(year_folder_path)
            new_file_path = os.path.join(year_folder_path, f"Table {t_no}.xls")
            os.rename(original_file_path, new_file_path)
            
        except Exception as e:
            print(f"Error occurred while downloading Table {t_no} for year {year1}: {str(e)}")
            continue

# Close the web driver
driver.quit()
# Out:
# /var/folders/46/nv05f1p17vq49bzzk_xwkl5w0000gn/T/ipykernel_42030/3037063150.py:26: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver_path, options=chrome_options)
# Error occurred while downloading Table 21 for year 2017: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/center[3]/table/tbody/tr/td[3]/a/img"}
#   (Session info: chrome=114.0.5735.198)
# Stacktrace:
# 0   chromedriver                        0x000000010113c598 chromedriver + 4973976
# 1   chromedriver                        0x0000000101133913 chromedriver + 4938003
# 2   chromedriver                        0x0000000100cf0cd6 chromedriver + 470230
# 3   chromedriver                        0x0000000100d342ff chromedriver + 746239
# 4   chromedriver                        0x0000000100d34591 chromedriver + 746897
# 5   chromedriver                        0x0000000100d76384 chromedriver + 1016708
# ...

# %%
import os
import shutil

# Define the base download directory
base_download_directory = r"/Users/chitrab/Downloads/Annual percentages"

# Define the mapping of original table names to new names for the years 2000 to 2016
table_names_2000_2016 = {
    "Table 13": "Table 1.1: Jordanian population by urban and rural, sex and age group (relative distribution)",
    "Table 14": "Table 1.2: Jordanian population by governorate, sex and age group (relative distribution)",
    "Table 15": "Table 2.1: Jordanian population aged 15 years and over by educational level, gender, and broad age groups (relative distribution)",
    "Table 16": "Table 2.2: Jordanian population aged 15 years and over by marital status, sex, and broad age groups (relative distribution)",
    "Table 17": "Table 2.3: Jordanian population aged 15 years and over by economic activity status, urban-rural, governorate and sex (relative distribution)",
    "Table 18": "Table 2.4: Jordanian population aged 15 years and over by economic activity status, gender, and broad age groups (relative distribution)",
    "Table 19": "Table 2.5: Jordanian population aged 15 years and over by economic activity status, sex, and educational level (relative distribution)",
    "Table 20": "Table 2.6: Jordanian population aged 15 years and over by economic activity status, gender and marital status (relative distribution)",
    "Table 21": "Table 3.1: Jordanian population aged 15-24 years, by status of economic activity, status of enrollment in educational institutions, age group, and sex (relative distribution)",
    "Table 22": "Table 4.1: Jordanian population aged 15 years and over and whose educational level is an intermediate diploma and above, by educational level, gender, and scientific specialization (relative distribution)",
    "Table 23": "Table 5.1: employed Jordanians aged 15 years and over by governorate, sex, and main age groups (relative distribution)",
    "Table 24": "Table 5.2: Jordanian employed persons aged 15 years and over by gender, main age groups, and educational level (relative distribution)",
    "Table 25": "Table 5.3: employed Jordanians aged 15 years and over by place of residence, place of work, and sex (relative distribution)",
    "Table 26": "Table 5.4: Employed Jordanians aged 15 years and over by governorate, gender, and current main economic activity (relative distribution)",
    "Table 27": "Table 5.5: employed Jordanians aged 15 years and over by main age groups, gender and current occupation (relative distribution)",
    "Table 28": "Table 5.6: employed Jordanians aged 15 years and over by governorate, gender and current occupation (relative distribution)",
    "Table 29": "Table 5.7: employed Jordanians aged 15 years and over by gender and current employment status (relative distribution)",
    "Table 30": "Table 5.8: employed Jordanians aged 15 years and over by educational level, gender, and current occupation (relative distribution)",
    "Table 31": "Table 5.9: Employed Jordanians aged 15 years and over by educational level, gender, and current main economic activity (relative distribution)",
    "Table 32": "Table 5.10: employed Jordanians aged 15 years and over by employment status, gender and current occupation (relative distribution)",
    "Table 33": "Table 5.11: employed Jordanians aged 15 years and over by employment status, gender, and current main economic activity (relative distribution)",
    "Table 34": "Table 5.12: employed Jordanians aged 15 years and over by current occupation, gender, and current main economic activity (relative distribution)",
    "Table 35": "Table 5.13: employed Jordanians aged 15 years and over by main age groups, gender and actual weekly working hours (relative distribution)",
    "Table 36": "Table 5.14: employed Jordanians aged 15 years and over by actual weekly working hours, governorate, and sex (relative distribution)",
    "Table 37": "Table 5.15: employed Jordanians aged 15 years and over by actual weekly working hours, current occupation, and gender (relative distribution)",
    "Table 38": "Table 5.16: employed Jordanians aged 15 years and over by actual weekly working hours, current main economic activity, and gender (relative distribution)",
    "Table 39": "Table 5.17: employed Jordanians aged 15 years and over by actual weekly working hours, current employment status, and gender (relative distribution)",
    "Table 40": "Table 5.18: Employed Jordanians aged 15 years and over by gender and current main economic activity (relative distribution)",
    "Table 41": "Table 5.19: employed Jordanians aged 15 years and over by gender and current occupation (relative distribution)",
    "Table 42": "Table 6.1: employed Jordanians aged 15 years and over who are absent from work by gender and reason for absence (relative distribution)",
    "Table 43": "Table 7.1: Employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender and main age groups (relative distribution)",
    "Table 44": "Table 7.2: Employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and governorate (relative distribution)",
    "Table 45": "Table 7.3: employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and actual weekly working hours (proportional distribution)",
    "Table 46": "Table 7.4: Employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and employment status (proportional distribution)",
    "Table 47": "Table 7.5: employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and educational level (proportional distribution)",
    "Table 48": "Table 7.6: employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and current occupation (proportional distribution)",
    "Table 49": "Table 7.7: Employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and current main economic activity (proportional distribution)",
    "Table 50": "Table 8.1: employed Jordanians aged 15 years and over who wish to work in another or overtime, by gender and main age groups (relative distribution)",
    "Table 51": "Table 8.2: employed Jordanians aged 15 years and over who wish to work in another or overtime, by gender and governorate (relative distribution)",
    "Table 52": "Table 8.3: employed Jordanians aged 15 years and over who desire other or overtime work by main age groups, gender and reason (relative distribution)",
    "Table 53": "Table 8.4: employed Jordanians aged 15 years and over who wish to work in another or overtime, by gender and current occupation (proportional distribution)",
    "Table 54": "Table 8.5: employed Jordanians aged 15 years and over who wish to work in another or additional work, by gender and current main economic activity (relative distribution)",
    "Table 55": "Table 8.6: employed Jordanians aged 15 years and over who wish to work in another or overtime, by gender and current employment status (proportional distribution)",
    "Table 56": "Table 9.1: Unemployed Jordanians aged 15 years and over by sex and main age groups (relative distribution)",
    "Table 57": "Table 2.9: Unemployed Jordanians aged 15 years and over by gender and governorate (relative distribution)",
    "Table 58": "Table 3.9: Unemployed Jordanians aged 15 years and over by gender and educational level (relative distribution)",
    "Table 59": "Table 9.4: Unemployed Jordanians aged 15 years and over by sex and marital status (relative distribution)",
    "Table 60": "Table 5.9: Unemployed Jordanians aged 15 years and over by sex and previous work status (relative distribution)",
    "Table 61": "Table 9.6: Unemployed Jordanians aged 15 years and over by gender and period of unemployment in months (relative distribution)",
    "Table 62": "Table 9.7: Unemployed Jordanians aged 15 years and over by gender and job search methods (relative distribution)",
    "Table 63": "Table 10.1: The Economically Inactive Jordanian Population Aged 15 Years and Over by Category, Sex, and Broad Age Groups (Percentage Distribution)",
    "Table 64": "Table 10.2: The Economically Inactive Jordanian Population Aged 15 Years and Over by Category, Sex, and Governorate (Percentage Distribution)",
    "Table 65": "Table 10.3: The Economically Inactive Jordanian Population Aged 15 Years and Over by Group, Sex, and Educational Level (Percentage Distribution)",
    "Table 66": "Table 10.4: Economically inactive Jordanian population aged 15 years and over who are available for work and are not looking for it by governorate, gender, and the main reason for not looking for work (relative distribution)",
    "Table 67": "Table 10.5: Economically inactive Jordanian population aged 15 years and over who are available for work and are not looking for it by main age groups, gender and main reason for not looking for work (relative distribution)"

}


# Create the temporary directory
temp_folder_path = os.path.join(base_download_directory, "temp")
os.makedirs(temp_folder_path, exist_ok=True)

# Loop through the years 2000 to 2016
for year in range(2000, 2017):
    # Get the path of the current year folder
    year_folder = str(year)
    year_folder_path = os.path.join(base_download_directory, year_folder)

    # Get the list of files within the current year folder
    files = os.listdir(year_folder_path)

    # Rename the files based on the table names mapping
    for file_name in files:
        original_file_path = os.path.join(year_folder_path, file_name)

        # Check if the file name matches the expected pattern
        if file_name.startswith("Table ") and file_name.endswith(".xls"):
            # Extract the table number from the original file name
            table_number = file_name.split(".")[0].split(" ")[-1]

            # Get the corresponding new table name from the mapping
            original_table_name = f"Table {table_number}"
            new_table_name = table_names_2000_2016.get(original_table_name, file_name)

            # Generate a unique identifier to replace the long file name
            unique_identifier = f"Table{table_number}"

            # Create the new file name using the unique identifier
            new_file_name = f"{unique_identifier}.xls"
            
            # Create the new file path in the temporary directory
            new_file_path = os.path.join(temp_folder_path, new_file_name)

            # Copy the file to the new path
            shutil.copyfile(original_file_path, new_file_path)

            # Remove the original file
            os.remove(original_file_path)

            # Move the new file to the year folder
            shutil.move(new_file_path, year_folder_path)

# Define the mapping of original table names to new ones for the years 2017 to 2022
table_names_2017_2022 = {
    "Table 13": "Table 1.1: Population by urban and rural, sex and age group (relative distribution)",
    "Table 14": "Table 1.3: Jordanian population by governorate, sex and age group (relative distribution)",
    "Table 15": "Table 2.1: Jordanian population aged 15 years and over by educational level, gender, and broad age groups (relative distribution)",
    "Table 16": "Table 2.3: Population aged 15 years and over by marital status, sex, broad age groups and nationality (relative distribution)",
    "Table 17": "Table 2.4: Jordanian population aged 15 years and over by economic activity status, urban and rural areas, governorates, and sex (relative distribution)",
    "Table 18": "Table 2.6: Population aged 15 years and over by economic activity status, gender, broad age groups, and nationality (relative distribution)",
    "Table 19": "Table 2.7: Population aged 15 years and over by economic activity status, sex, educational level and nationality (relative distribution)",
    "Table 20": "Table 2.8: Population aged 15 years and over by economic activity status, sex, marital status, and nationality (relative distribution)",
    "Table 23": "Table 4.1: Employed Persons Aged 15 Years and Over by Gender, Broad Age Groups, and Nationality (Percentage Distribution)",
    "Table 32": "Table 4.7: Employed Persons Aged 15 Years and Over by Actual Weekly Work Hours, Gender and Nationality (Percentage Distribution)",
    "Table 33": "Table 6.2: employed Jordanians aged 15 years and over who are looking for other or additional work by gender and educational level (relative distribution)",
    "Table 34": "Table 5.1: Employed Persons Aged 15 Years and Over by Categories of Monthly Work Income (in Dinars), Gender, Main Age Groups, and Nationality (Percentage Distribution)",
    "Table 36": "Table 5.3: employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars), gender, and actual weekly working hours (proportional distribution)",
    "Table 38": "Table 5.4: Employed Persons Aged 15 Years and Over by Categories of Monthly Work Income (in Dinars), Gender, Education Level, and Nationality (Percentage Distribution)",
    "Table 39": "Table 6.1: employed Jordanians aged 15 years and over who are looking for other or additional work by sex and main age groups (relative distribution)",
    "Table 41": "Table 7.1: Unemployed persons aged 15 years and over by gender, main age groups, and nationality (relative distribution)",
    "Table 42": "Table 2.7: Unemployed persons aged 15 years and over by gender, governorate and nationality (relative distribution)",
    "Table 43": "Table 7.3: Unemployed persons aged 15 years and over by gender, educational level and nationality (relative distribution)",
    "Table 44": "Table 4.7: Unemployed persons aged 15 years and over by gender, marital status and nationality (relative distribution)",
    "Table 45": "Table 7.5: Unemployed persons aged 15 years and over by gender, previous work status and nationality (relative distribution)",
    "Table 46": "Table 7.6: Unemployed persons aged 15 years and over by gender, period of unemployment in months, and nationality (relative distribution)",
    "Table 47": "Table 7.7: Unemployed Jordanians aged 15 years and over by gender and job search methods (percentage)",
    "Table 70": "Table 1.2: Population by nationality, sex and age group (relative distribution)",
    "Table 71": "Table 1.4: Non-Jordanian Population by Governorate, Sex and Age Group (Percentage Distribution)",
    "Table 72": "Table 2.2: Non-Jordanian population aged 15 years and over by educational level, sex, and broad age groups (relative distribution)",
    "Table 73": "Table 5.2: Non-Jordanian population aged 15 years and over by economic activity status, urban and rural areas, governorates and sex (relative distribution)",
    "Table 74": "Table 4.3: Employed Persons Aged 15 Years and Over by Gender, Governorate and Nationality (Percentage Distribution)",
    "Table 75": "Table 5.5: employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars) and occupation (proportional distribution)",
    "Table 76": "Table 3.1: Population aged 15-24 years by status of economic activity, status of enrollment in educational institutions, nationality, and sex (relative distribution)",
    "Table 77": "Table 4.2: Employed Persons Aged 15 Years and Over by Gender, Main Age Groups, Educational Level, and Nationality (Percentage Distribution)",
    "Table 78": "Table 4.4: Employed Persons Aged 15 Years and Over by Governorate, Gender, Current Main Economic Activity, and Nationality (Percentage Distribution)",
    "Table 79": "Table 4.5: Employed Persons Aged 15 Years and Over by Gender, Current Occupation, and Nationality (Percentage Distribution)",
    "Table 80": "Table 4.6: Employed Persons Aged 15 Years and Over by Gender, Current Employment Status, and Nationality (Percentage Distribution)",
    "Table 81": "Table 5.2: Employed Jordanians aged 15 years and over by categories of monthly income from work (in dinars) and governorate (proportional distribution)",
    "Table 82": "Table 4.9: employed Jordanians aged 15 years and over by employment status, gender, and current main economic activity (relative distribution)",
    "Table 83": "Table 4.10: employed Jordanians aged 15 years and over by work sector and gender (relative distribution)",
    "Table 84": "Table 4.11: employed Jordanians aged 15 years and over by gender and employment status (relative distribution)",
    "Table 85": "Table 2.9: Jordanian population aged 15 years and over by educational level, sex, and governorate (relative distribution)",
    "Table 86": "Table 2.10: Unemployment rate for the Jordanian population aged 15 years and over, by governorate and sex"
}

# Loop through the years 2017 to 2022
for year in range(2017, 2023):
    # Get the path of the current year folder
    year_folder = str(year)
    year_folder_path = os.path.join(base_download_directory, year_folder)

    # Get the list of files within the current year folder
    files = os.listdir(year_folder_path)

    # Rename the files based on the table names mapping
    for file_name in files:
        original_file_path = os.path.join(year_folder_path, file_name)

        # Check if the file name matches the expected pattern
        if file_name.startswith("Table ") and file_name.endswith(".xls"):
            # Extract the table number from the original file name
            table_number = file_name.split(".")[0].split(" ")[-1]

            # Get the corresponding new table name from the mapping
            original_table_name = f"Table {table_number}"
            new_table_name = table_names_2017_2022.get(original_table_name, file_name)

            # Generate a unique identifier to replace the long file name
            unique_identifier = f"Table{table_number}"

            # Create the new file name using the unique identifier
            new_file_name = f"{unique_identifier}.xls"
            
            # Create the new file path in the temporary directory
            new_file_path = os.path.join(temp_folder_path, new_file_name)

            # Copy the file to the new path
            shutil.copyfile(original_file_path, new_file_path)

            # Remove the original file
            os.remove(original_file_path)

            # Move the new file to the year folder
            shutil.move(new_file_path, year_folder_path)

# Remove the temporary directory
shutil.rmtree(temp_folder_path)

# Confirm the files have been renamed
print("Files renamed successfully.")
# Out:
# Files renamed successfully.
