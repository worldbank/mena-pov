# %% [markdown]
# # MENA Analysis: Urban Density
# ## 2000 -2020

# %% [markdown]
# ### Load packages and setup

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from rasterstats import zonal_stats
import rasterio
import rioxarray
import xarray

# %%
# Define directories
dir_shp = '/Users/ashitakarl/Library/CloudStorage/Dropbox/WB/MENA_WorldBank/Boundaries/'
dir_in = '/Users/ashitakarl/Desktop/Project/WB/MENA/ECMRWF/'
dir_out = '/Users/ashitakarl/Library/CloudStorage/Dropbox/WB/MENA_WorldBank/Index/'

# Define output FILE
VAR = 'URBAN_'
YEAR_LIST = [2000, 2005, 2010, 2015, 2020]
FILE_OUT = 'ADM2_' + VAR + str(min(YEAR_LIST)) + '_' + str(max(YEAR_LIST)) + '.csv'

# %%
# %matplotlib inline

# %% [markdown]
# ### Load shapefile

# %%
# Load shapefile
MENA_shp = gpd.read_file(dir_shp + 'MENA_ADM2.shp')

MENA_shp.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Load urban density rasters

# %% [raw]
# for YEAR in YEAR_LIST:
#     xds = xarray.open_dataset(dir_in + str(YEAR) + '.nc')
#     xds["lccs_class"].rio.write_crs("EPSG:4326", inplace = True)
#     xds["lccs_class"].rio.to_raster(dir_in + str(YEAR) + '.tif')

# %% [raw]
# df_full = pd.DataFrame(MENA_shp['ID_ADM'])
#
# for YEAR in YEAR_LIST:
#     with rasterio.open(dir_in + str(YEAR) + '.tif') as raster:
#         array = raster.read(1)
#         affine = raster.transform
#         nodata = raster.nodata
#
#     #MENA_shp.to_crs(raster.crs, inplace = True)
#
#     # Extract raster by polygon
#     dict_temp = zonal_stats(MENA_shp, array, affine = affine, nodata = nodata,
#                           stats = ['count'], categorical = True)
#     df_temp = pd.DataFrame(dict_temp)
#     df_temp = df_temp.add_prefix(VAR)
#     if 'URBAN_190' in df_temp.columns:
#         df_temp['URBAN'] = df_temp['URBAN_190']
#     else:
#         df_temp['URBAN'] = 0
#     df_temp = df_temp[['URBAN', 'URBAN_count']]
#     df_temp['URBAN_DEN'] = (df_temp['URBAN'] / df_temp['URBAN_count']) * 100
#     df_temp = df_temp.add_suffix('_' + str(YEAR))
#     df_temp.insert(0, 'ID_ADM', MENA_shp['ID_ADM'])
#
#     df_full = df_full.merge(df_temp, how = 'left', on = 'ID_ADM')

# %%
df_full = df_full[['ID_ADM', 'URBAN_2000', 'URBAN_DEN_2000', 'URBAN_2005', 'URBAN_DEN_2005',
                  'URBAN_2010', 'URBAN_DEN_2010', 'URBAN_2015', 'URBAN_DEN_2015', 
                  'URBAN_2020', 'URBAN_DEN_2020', 'URBAN_count_2000']]

df_full.rename(columns = {'URBAN_count_2000': 'URBAN_ttl_pixel'})
# Out:
#       ID_ADM  URBAN_2000  URBAN_DEN_2000  URBAN_2005  URBAN_DEN_2005  \
# 0      37631        70.0        0.852204        70.0        0.852204
# 1      37632         NaN             NaN         NaN             NaN
# 2      37633        58.0        0.034075        68.0        0.039949
# 3      37634         NaN             NaN         NaN             NaN
# 4      37635         NaN             NaN         NaN             NaN
# ...      ...         ...             ...         ...             ...
# 2932   15561       640.0        1.392940       831.0        1.808645
# 2933   15562       165.0        0.008627       246.0        0.012862
# 2934   15563        57.0        0.127130       284.0        0.633420
# 2935   15564        75.0        0.022481        86.0        0.025778
# 2936   15565        49.0        0.158874       228.0        0.739252
#
#       URBAN_2010  URBAN_DEN_2010  URBAN_2015  URBAN_DEN_2015  URBAN_2020  \
# ...

# %%
df_full.fillna(0, inplace=True)

# %%
df_full.to_csv(dir_out + FILE_OUT, index = False)
